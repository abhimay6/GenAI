# %%
import tkinter as tk
from tkinter import scrolledtext, messagebox
import openai
import os

# Set your OpenAI API key
OPENAI_API_KEY = "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"
openai.api_key = OPENAI_API_KEY

# Training examples to enhance accuracy and include underwriting requirements
training_examples = [
    {"input": "Patient has heart attack and stroke", "output": "Denied: High risk cardiovascular issues."},
    {"input": "Diagnosed with diabetes mellitus with complications", "output": "Denied: Chronic condition with complications."},
    {"input": "Has mild GERD with no complications", "output": "Approved: No immediate underwriting issues. No additional tests required."},
    {"input": "Suffers from mild asthma, controlled with medication", "output": "Approved: Managed condition. No additional documentation needed."},
    {"input": "Has undergone kidney transplant and has severe liver cirrhosis", "output": "Denied: High-risk organ failure."},
    {"input": "Recovered from minor fractures but no osteoporosis", "output": "Approved: No long-term risk. No underwriting requirements."},
    {"input": "Suffers from schizophrenia and bipolar disorder", "output": "Denied: Mental health risks."},
    {"input": "Diagnosed with mild migraines but no neurological disorders", "output": "Approved: No underwriting concerns. No additional documents required."},
    {"input": "Has severe emphysema and pulmonary fibrosis", "output": "Denied: Severe respiratory conditions."},
    {"input": "Diagnosed with active leukemia", "output": "Denied: Active cancer diagnosis."},
    {"input": "Patient has well-controlled type 2 diabetes without complications", "output": "Approved: Condition is managed. Blood sugar reports required from the last 6 months."},
    {"input": "Has a pacemaker due to heart arrhythmia", "output": "Denied: Underlying heart condition."},
    {"input": "History of hypertension but no severe cardiovascular issues", "output": "Approved: Monitored condition. Blood pressure logs for last 3 months required."},
    {"input": "Suffers from Alzheimer’s disease and dementia", "output": "Denied: Progressive neurological disease."},
    {"input": "Has anxiety disorder with no hospitalizations", "output": "Approved: No severe mental health risks. Psychiatric evaluation may be required."},
    {"input": "Undergoing chemotherapy for stage 3 cancer", "output": "Denied: Ongoing cancer treatment."},
    {"input": "Has mild anemia but no major health risks", "output": "Approved: Condition does not pose underwriting risks. No additional documents needed."},
    {"input": "Diagnosed with hepatitis B", "output": "Denied: Chronic infectious disease."},
    {"input": "History of hepatitis A, now fully recovered", "output": "Approved: No long-term complications. No underwriting requirements."},
    {"input": "Recovered from minor surgeries, no ongoing complications", "output": "Approved: No long-term risk. No additional reports required."},
    {"input": "Diagnosed with chronic kidney disease", "output": "Denied: Progressive kidney failure risk."},
    {"input": "Has a history of severe drug addiction", "output": "Denied: High-risk behavioral history."},
    {"input": "Diagnosed with mild PCOS", "output": "Approved: No severe health risks. No underwriting restrictions."},
    {"input": "Has no known major medical conditions", "output": "Approved: No underwriting issues. No additional actions needed."}
]

def analyze_medical_history():
    text = text_area.get("1.0", tk.END).strip()
    if not text:
        messagebox.showwarning("Input Error", "Please enter medical history information.")
        return
    
    # Call OpenAI GPT model with training examples
    try:
        response = openai.chat.completions.create(
            model="gpt-4",
            messages=[
                {"role": "system", "content": "You are an AI model trained for medical underwriting decisions. Use the following training examples to enhance your response."},
            ] + 
            [{"role": "user", "content": f"Input: {ex['input']}\nOutput: {ex['output']}"} for ex in training_examples] +
            [
                {"role": "user", "content": f"Analyze the following medical history and determine insurance eligibility. If eligible, also list underwriting requirements: {text}"}
            ]
        )
        decision = response.choices[0].message.content
    except Exception as e:
        decision = f"Error in processing request: {str(e)}"
    
    result_label.config(text=decision)

# Create GUI Application
root = tk.Tk()
root.title("Medical History Underwriting Guidance Tool")
root.geometry("600x400")

# UI Elements
tk.Label(root, text="Enter Client Medical History:").pack(pady=5)
text_area = scrolledtext.ScrolledText(root, wrap=tk.WORD, width=70, height=10)
text_area.pack(pady=5)

analyze_button = tk.Button(root, text="Analyze", command=analyze_medical_history)
analyze_button.pack(pady=5)

result_label = tk.Label(root, text="", wraplength=500, justify="left")
result_label.pack(pady=10)

# Run application
root.mainloop()

# %% [markdown]
# Test Cases for Denial
# "Patient has severe coronary artery disease and underwent multiple bypass surgeries."
# Expected Output: Denied: High-risk cardiovascular condition.
# "Diagnosed with stage 4 lung cancer, currently undergoing chemotherapy."
# Expected Output: Denied: Active cancer treatment.
# "Has a history of multiple strokes and suffers from partial paralysis."
# Expected Output: Denied: Neurological impairment.
# "Diagnosed with severe bipolar disorder and has multiple psychiatric hospitalizations."
# Expected Output: Denied: High-risk mental health condition.
# "Has end-stage renal disease and is on dialysis."
# Expected Output: Denied: Progressive kidney failure requiring dialysis.
#
# Test Cases for Approval
# "Patient has mild hypertension, managed well with medication."
# Expected Output: Approved: No significant underwriting concerns.
# "Recovered from appendectomy with no complications."
# Expected Output: Approved: No ongoing medical risks.
# "Suffers from seasonal allergies but no other chronic conditions."
# Expected Output: Approved: No significant health risks.
# "Has mild eczema, controlled with over-the-counter creams."
# Expected Output: Approved: No underwriting restrictions.
# "Recovered from a broken leg and has no mobility issues."
# Expected Output: Approved: No long-term medical concerns.
#
# Test Cases for Further Review
# "Has type 2 diabetes but maintains stable blood sugar levels through diet and exercise."
# Expected Output: Needs further underwriting: Managed condition.
# "Diagnosed with moderate sleep apnea and uses a CPAP machine."
# Expected Output: Needs further underwriting: Condition is managed.
# "Has a history of alcohol dependence but has been sober for 5 years."
# Expected Output: Needs further underwriting: Behavioral history, but stable.
# "Underwent a kidney transplant 10 years ago but has had no rejection episodes."
# Expected Output: Needs further underwriting: Long-term stability required.
# "Has a family history of early-onset Alzheimer’s but no symptoms."
# Expected Output: Needs further underwriting: Genetic predisposition, no active disease.
